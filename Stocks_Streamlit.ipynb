# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as d 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../yfinance_Project/Stock_NS.csv")

# %%
df
# Out:
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2025-01-01   689.276855   690.534052   676.426097
# 1              1  2025-01-02   734.388428   738.443423   692.824889
# 2              2  2025-01-03   736.182373   745.400517   731.411822
# 3              3  2025-01-06   730.427917   755.329257   727.187900
# 4              4  2025-01-07   730.885071   740.123050   725.667267
# ...          ...         ...          ...          ...          ...
# 2548         269  2026-02-02  1023.900024  1052.400024  1010.200012
# 2549         270  2026-02-03  1032.300049  1063.699951  1020.200012
# 2550         271  2026-02-04  1028.500000  1037.400024  1021.700012
# 2551         272  2026-02-05  1035.400024  1059.900024  1028.800049
# 2552         273  2026-02-06  1035.699951  1046.000000  1030.099976
#
#              Open    Volume           Stock
# 0      678.115684   4187210    BajajFinance
# 1      693.719394  31716510    BajajFinance
# 2      734.443105  15059280    BajajFinance
# 3      745.400532  19059760    BajajFinance
# 4      730.984433  10425380    BajajFinance
# ...           ...       ...             ...
# 2548  1025.099976     77943  PageIndustries
# 2549  1055.000000     72964  PageIndustries
# 2550  1032.300049     50347  PageIndustries
# 2551  1033.000000     89660  PageIndustries
# 2552  1037.900024     85232  PageIndustries
#
# [2553 rows x 8 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Close         float64
# High          float64
# Low           float64
# Open          float64
# Volume          int64
# Stock          object
# dtype: object

# %%
df.Date=df.Date.astype('datetime64[ns]')

# %%
print(df.Stock.unique())
st=input ("Enter Stock Name:")
r=df[df.Stock==st]

sb.lineplot(x=r.Date,y=r.Close)
plt.xticks(rotation=90)
plt.show()
# Out:
# ['BajajFinance' 'ShriRamFinance' 'JioFinancial' 'IRFC' 'MuthootFinance'
#  'TataCapital' 'Cholaman.Inv.&Fn' 'Trent Ltd' 'MetroBrands'
#  'PageIndustries']
# Enter Stock Name: BajajFinance
